# %% [markdown]
# # Sugestões de Rotas ciclicas para Transporte de Ônibus Urbano

# %%
from _thread import *
from IPython.display import IFrame

import random
import threading
import osmnx as ox
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import time

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Configuração para o algoritmo genético

# %%
totGeracoes  = 50
tamPopulacao = 20


indCruzamento = 10
CXPB = 0.5
MUTPB = 0.1
PROB_MUTACAO = 0.1
SEED_RANDOM = 64
#minimoAceitavel = 1
#pontuação baixo será eliminada do grafo
removerPior = 0

#fornecer ajuda para a evolucao do método
recebeAjuda  = True
ajudaQtd = 30

#Reforço no aprendizado
reforco = False

# Ajuste de 1.0 -> maximização ou -1.0 -> minimização da feature
feature1 = 1.0 #onemax
feature2 = 1.0 #dfs
feature3 = 1.0 #distancia dfs
feature4 = 1.0 #tam ciclo
feature5 = 1.0 #distancia ciclo

# %% [markdown]
# # Formato Imagens

# %%
'''
    Formatos Suportados salvar rotas e mapas: eps, pdf, pgf, png, ps, raw, rgba, svg, svgz 
'''
formato_imgs = 'pdf'

# %% [markdown]
# # Configuração da Imagens

# %%
'''
    configuração da imagens
'''
edge_color = "#000000"     # cor da aresta
bgcolor    = "#D3D3D3"     # cor do background
node_color = "#9370DB"     # cor da vértice
node_size  = 10            # Tamanho do vértice
fig_height = 20           # altura figura
fig_width  = 20           # largura figura

# %% [markdown]
# # Localização para o OSMNX gerar o Grafo

# %%
try:
    place = 'Boa Vista, Roraima, BR'
    Raio_distancia = 15000

    G = ox.graph_from_address( place, network_type='drive', simplify=True, distance=Raio_distancia )
except:
    print("Falha na Conexão!!")

# %%
ox.plot_graph(G, fig_height=fig_height, fig_width=fig_width, edge_color=edge_color, bgcolor=bgcolor, node_color=node_color, node_size=node_size, filename="mapaCompleto", save=True, file_format=formato_imgs)
# Out:
# (<Figure size 1440x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f60424c6f60>)

# %% [markdown]
# # Vértice que representa o terminal de ônibus

# %%
nodosCentroCivico = ( 3648084763, 3648084762 )

# %% [markdown]
# # Extrai as informações das via do Grafo G

# %%
listaDados = []

dado = G.adj
for i in dado:
    for j in dado[i]:
        for k in dado[i][j]:
            h = []
            h.append(i)
            h.append(j)
            h.append(dado[i][j][k])
            listaDados.append(h)
            
listaDados
# Out:
# [[3542810654,
#   3542790331,
#   {'osmid': 348047232,
#    'oneway': True,
#    'name': 'Avenida A',
#    'highway': 'residential',
#    'length': 340.996}],
#  [3542810654,
#   5000996632,
#   {'osmid': 519374475,
#    'oneway': True,
#    'name': 'Avenida Pérola',
#    'highway': 'residential',
#    'length': 13.196}],
#  [3542810655,
#   3542790324,
#   {'osmid': 348047241,
#    'name': 'Avenida Normandia',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 67.753}],
#  [3542810655,
#   3542810656,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 159.589}],
#  [3542810655,
#   3542790342,
#   {'osmid': 348047241,
#    'name': 'Avenida Normandia',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 68.383,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e4a4b70>}],
#  [3542810656,
#   3542790337,
#   {'osmid': 348047239,
#    'oneway': True,
#    'name': 'Avenida Uiramutã',
#    'highway': 'residential',
#    'length': 68.246}],
#  [3542810656,
#   5000993210,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 9.175}],
#  [3542810656,
#   3542810655,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 159.589}],
#  [3542810657,
#   5000993220,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 13.771}],
#  [3542810657,
#   5000993210,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 259.111}],
#  [3542810657,
#   3542790332,
#   {'osmid': 511187822,
#    'oneway': True,
#    'name': 'Avenida A',
#    'highway': 'residential',
#    'length': 67.303}],
#  [3542810658,
#   1723381170,
#   {'osmid': 160283818,
#    'oneway': True,
#    'name': 'Rua dos Trabalhadores',
#    'highway': 'residential',
#    'length': 65.876}],
#  [3542810658,
#   5000993220,
#   {'osmid': 348049270,
#    'name': 'Rua José Maria Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 324.802}],
#  [321519672,
#   6947307083,
#   {'osmid': 704201746,
#    'oneway': True,
#    'name': 'Rua Coronel Pinto',
#    'highway': 'tertiary',
#    'length': 17.776}],
#  [321519672,
#   3648084764,
#   {'osmid': 154903789,
#    'oneway': True,
#    'lanes': '2',
#    'name': 'Avenida Capitão Júlio Bezerra',
#    'highway': 'secondary',
#    'length': 150.094,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862bef0>}],
#  [321519687,
#   1067748890,
#   {'osmid': 157934959,
#    'name': 'Rua Alfredo Cruz',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 106.031,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862b390>}],
#  [321519687,
#   1067749027,
#   {'osmid': 392879709,
#    'oneway': False,
#    'name': 'Rua Professor Agnelo Bitencourt',
#    'highway': 'tertiary',
#    'length': 144.93,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862bf60>}],
#  [321519687,
#   1067749186,
#   {'osmid': 392879710,
#    'name': 'Rua Alfredo Cruz',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 94.822,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862bac8>}],
#  [6929449050,
#   1712831478,
#   {'osmid': 159188184,
#    'name': 'Rua São Marcos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 100.126}],
#  [6929449050,
#   1712842200,
#   {'osmid': 159188184,
#    'name': 'Rua São Marcos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 7.364}],
#  [6929449050,
#   1712842187,
#   {'osmid': 159189107,
#    'name': 'Rua São Leopoldo',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 177.807}],
#  [321519708,
#   3844659245,
#   {'osmid': 154903752,
#    'oneway': True,
#    'name': 'Avenida Benjamin Constant',
#    'highway': 'secondary',
#    'length': 37.558}],
#  [321519708,
#   1067748805,
#   {'osmid': 154903729,
#    'name': 'Rua Antônio Bitencourt',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 136.34199999999998,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862bb70>}],
#  [321519710,
#   2171726897,
#   {'osmid': 492110875,
#    'oneway': True,
#    'name': 'Avenida Benjamin Constant',
#    'highway': 'secondary',
#    'length': 12.576}],
#  [321519710,
#   6949029692,
#   {'osmid': 739170347,
#    'oneway': True,
#    'lanes': '3',
#    'ref': 'BR-401',
#    'name': 'Avenida das Guianas',
#    'highway': 'secondary',
#    'length': 138.025}],
#  [6929449052,
#   5048443230,
#   {'osmid': 517322719,
#    'oneway': True,
#    'name': 'Rua Raio de Sol',
#    'highway': 'tertiary',
#    'length': 53.088,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862b9b0>}],
#  [6929449052,
#   5048443227,
#   {'osmid': 517322725,
#    'oneway': True,
#    'highway': 'secondary',
#    'length': 22.436,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862b908>}],
#  [321519718,
#   1688796363,
#   {'osmid': 29231442,
#    'oneway': False,
#    'ref': 'BR-401',
#    'highway': 'primary',
#    'maxspeed': '60',
#    'length': 26.6}],
#  [321519718,
#   3829177508,
#   {'osmid': 29231442,
#    'oneway': False,
#    'ref': 'BR-401',
#    'highway': 'primary',
#    'maxspeed': '60',
#    'length': 1402.9560000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862b7f0>}],
#  [321519718,
#   3829177508,
#   {'osmid': [379585016, 379584999],
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 1570.8270000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862bb38>}],
#  [4305256646,
#   4305256647,
#   {'osmid': 160008981,
#    'name': 'Rua Z-3',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 40.643}],
#  [4305256647,
#   1720705896,
#   {'osmid': 160008979,
#    'name': 'Rua Francisco Anacleto da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 164.23}],
#  [4305256647,
#   6929512949,
#   {'osmid': 160008981,
#    'name': 'Rua Z-3',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 14.324}],
#  [4305256647,
#   4305256646,
#   {'osmid': 160008981,
#    'name': 'Rua Z-3',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 40.643}],
#  [6839599394,
#   1722212202,
#   {'osmid': 160150860,
#    'name': 'Rua dos Trabalhadores',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 15.107}],
#  [6839599394,
#   1722188834,
#   {'osmid': 160150860,
#    'name': 'Rua dos Trabalhadores',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 127.768}],
#  [6839599394,
#   6839599395,
#   {'osmid': 430851700,
#    'oneway': True,
#    'name': 'Rua HC-13',
#    'highway': 'residential',
#    'length': 14.151}],
#  [6839599395,
#   1722212202,
#   {'osmid': 160148908,
#    'oneway': True,
#    'name': 'Rua HC-13',
#    'highway': 'residential',
#    'length': 15.588}],
#  [6839599395,
#   1722188776,
#   {'osmid': 430851877,
#    'name': 'Rua HC-13',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 227.878,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862b940>}],
#  [3207791013,
#   3542821654,
#   {'osmid': 160283818,
#    'oneway': True,
#    'name': 'Rua dos Trabalhadores',
#    'highway': 'residential',
#    'length': 64.696}],
#  [3207791013,
#   6758200278,
#   {'osmid': 669630560,
#    'name': 'Rua Aristoteles de Lima Carneiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 301.218}],
#  [4297261503,
#   1721129691,
#   {'osmid': 430452894,
#    'oneway': True,
#    'name': 'Avenida Nazaré Filgueiras',
#    'highway': 'secondary',
#    'maxspeed': '50',
#    'length': 67.48}],
#  [4297261503,
#   1721068501,
#   {'osmid': [655955996, 312824254],
#    'name': 'Rua Raimundo Pessoa de Almeida',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 76.44600000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605862ba20>}],
#  [1728313863,
#   1728313897,
#   {'osmid': 160808826,
#    'name': 'Travessa Nicarágua I',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 33.424}],
#  [1728313863,
#   1706562593,
#   {'osmid': 718625208,
#    'oneway': False,
#    'name': 'Rua Nicarágua',
#    'highway': 'residential',
#    'length': 86.924}],
#  [1728313863,
#   1706562507,
#   {'osmid': 718625208,
#    'oneway': False,
#    'name': 'Rua Nicarágua',
#    'highway': 'residential',
#    'length': 100.689}],
#  [5052236310,
#   2171726920,
#   {'osmid': 361809508,
#    'name': 'Rua Deuzuita Mutran Paracat',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 65.795}],
#  [5052236310,
#   5052236311,
#   {'osmid': 517786756,
#    'name': 'Rua de Acesso',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 125.611}],
#  [5052236310,
#   1701116357,
#   {'osmid': [157869163, 361809508],
#    'name': ['Rua Deuzuita Mutran Paracat', 'Rua do Iate'],
#    'highway': 'residential',
#    'oneway': False,
#    'length': 348.299,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b278>}],
#  [5052236311,
#   5052236310,
#   {'osmid': 517786756,
#    'name': 'Rua de Acesso',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 125.611}],
#  [5057484062,
#   3518106633,
#   {'osmid': 529714689,
#    'oneway': True,
#    'name': 'Avenida Equador',
#    'highway': 'tertiary',
#    'length': 263.342}],
#  [5057484062,
#   5057484061,
#   {'osmid': 529714690,
#    'oneway': True,
#    'highway': 'tertiary',
#    'junction': 'roundabout',
#    'length': 14.556000000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f39c50>}],
#  [1728313897,
#   1728313863,
#   {'osmid': 160808826,
#    'name': 'Travessa Nicarágua I',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 33.424}],
#  [1728313897,
#   1728313919,
#   {'osmid': 160808826,
#    'name': 'Travessa Nicarágua I',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 114.454}],
#  [1728313897,
#   4562233073,
#   {'osmid': [160808820, 721768045],
#    'name': 'Travessa Nicarágua II',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 122.07400000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040ac3358>}],
#  [1685324565,
#   1685324587,
#   {'osmid': 156272272,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 140.379}],
#  [1685324565,
#   1934377606,
#   {'osmid': 262676986,
#    'name': 'Rua Sócrates Peixoto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 96.914}],
#  [1685324565,
#   1685324559,
#   {'osmid': 156272272,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 225.108,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b7b8>}],
#  [1685324559,
#   1684682928,
#   {'osmid': 51332294,
#    'oneway': True,
#    'lanes': '2',
#    'name': 'Rua Yeyê Coelho',
#    'highway': 'secondary',
#    'length': 27.496}],
#  [1685324559,
#   1685324565,
#   {'osmid': 156272272,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 225.108,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b780>}],
#  [1685324561,
#   1685324569,
#   {'osmid': 156272270,
#    'oneway': False,
#    'name': 'Travessa Jasmim',
#    'highway': 'residential',
#    'length': 177.131}],
#  [1685324561,
#   1685324563,
#   {'osmid': 160830743,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 75.335}],
#  [1685324561,
#   1684682928,
#   {'osmid': 160830743,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 36.667}],
#  [1685324569,
#   1684682924,
#   {'osmid': 51332304,
#    'name': 'Rua Francisco Cândido',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 65.06}],
#  [1685324569,
#   1685324571,
#   {'osmid': 51332304,
#    'name': 'Rua Francisco Cândido',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 74.895}],
#  [1685324569,
#   1685324561,
#   {'osmid': 156272270,
#    'oneway': False,
#    'name': 'Travessa Jasmim',
#    'highway': 'residential',
#    'length': 177.131}],
#  [1685324569,
#   1685324575,
#   {'osmid': 156272270,
#    'oneway': False,
#    'name': 'Travessa Jasmim',
#    'highway': 'residential',
#    'length': 147.827}],
#  [1685324563,
#   1685324571,
#   {'osmid': 156272271,
#    'oneway': False,
#    'name': 'Travessa Jaraguá',
#    'highway': 'residential',
#    'length': 179.566}],
#  [1685324563,
#   1925415294,
#   {'osmid': 160830743,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 137.781}],
#  [1685324563,
#   1685324561,
#   {'osmid': 160830743,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 75.335}],
#  [1685324571,
#   1685324569,
#   {'osmid': 51332304,
#    'name': 'Rua Francisco Cândido',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 74.895}],
#  [1685324571,
#   1925415293,
#   {'osmid': 51332304,
#    'name': 'Rua Francisco Cândido',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 154.647}],
#  [1685324571,
#   1685324563,
#   {'osmid': 156272271,
#    'oneway': False,
#    'name': 'Travessa Jaraguá',
#    'highway': 'residential',
#    'length': 179.566}],
#  [1685324571,
#   1685324575,
#   {'osmid': [156272273, 156272271],
#    'oneway': False,
#    'name': ['Travessa Jaraguá', 'Rua Senhora Cecília'],
#    'highway': 'residential',
#    'length': 218.15999999999997,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b860>}],
#  [1685324575,
#   1685324569,
#   {'osmid': 156272270,
#    'oneway': False,
#    'name': 'Travessa Jasmim',
#    'highway': 'residential',
#    'length': 147.827}],
#  [1685324575,
#   1685324571,
#   {'osmid': [156272273, 156272271],
#    'oneway': False,
#    'name': ['Rua Senhora Cecília', 'Travessa Jaraguá'],
#    'highway': 'residential',
#    'length': 218.15999999999997,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b7f0>}],
#  [1685324575,
#   1685324579,
#   {'osmid': 156272273,
#    'oneway': False,
#    'name': 'Rua Senhora Cecília',
#    'highway': 'residential',
#    'length': 88.49199999999999,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b8d0>}],
#  [1685324579,
#   655057565,
#   {'osmid': 730900586,
#    'oneway': True,
#    'lanes': '2',
#    'name': 'Rua Yeyê Coelho',
#    'highway': 'secondary',
#    'length': 95.75}],
#  [1685324579,
#   1685324575,
#   {'osmid': 156272273,
#    'oneway': False,
#    'name': 'Rua Senhora Cecília',
#    'highway': 'residential',
#    'length': 88.49199999999999,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b828>}],
#  [1685324581,
#   1683886515,
#   {'osmid': 156080527,
#    'oneway': False,
#    'name': 'Rua Deco Fonteles',
#    'highway': 'residential',
#    'length': 74.307}],
#  [1685324581,
#   1685324555,
#   {'osmid': 156272275,
#    'oneway': False,
#    'name': 'Travessa Jardim Floresta',
#    'highway': 'residential',
#    'length': 174.314}],
#  [1685324581,
#   655057592,
#   {'osmid': 156080527,
#    'oneway': False,
#    'name': 'Rua Deco Fonteles',
#    'highway': 'residential',
#    'length': 87.541,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b898>}],
#  [1685324587,
#   655057576,
#   {'osmid': 31481169,
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'length': 115.247}],
#  [1685324587,
#   1685324565,
#   {'osmid': 156272272,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 140.379}],
#  [1685324587,
#   1687960941,
#   {'osmid': 156272272,
#    'oneway': False,
#    'name': 'Rua João Magalhães',
#    'highway': 'residential',
#    'length': 165.454}],
#  [1719599961,
#   1719600022,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 44.505}],
#  [1719599961,
#   1426836628,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 42.238}],
#  [1719599961,
#   1719600047,
#   {'osmid': 159874355,
#    'name': 'Rua Dona Cota Vieira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.48199999999997,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b908>}],
#  [1719599965,
#   1687960955,
#   {'osmid': 129300229,
#    'name': 'Rua Jair Alves dos Reis',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 151.847}],
#  [1719599965,
#   1719600058,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 97.666}],
#  [1719599965,
#   1719600050,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 92.507}],
#  [1719599965,
#   1426836626,
#   {'osmid': 719078558,
#    'name': 'Rua Jair Alves dos Reis',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 132.402,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b940>}],
#  [1719599981,
#   1719600088,
#   {'osmid': 159841154,
#    'name': 'Rua Jorge Fraxe',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.797}],
#  [1719599981,
#   1713308953,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 102.787}],
#  [1719599981,
#   1719600062,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.12}],
#  [1719599981,
#   1719383746,
#   {'osmid': 159841154,
#    'name': 'Rua Jorge Fraxe',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.425,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18ba20>}],
#  [1719599978,
#   1426836628,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 11.954}],
#  [1719599978,
#   1719600089,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 61.947}],
#  [1719599978,
#   1719600082,
#   {'osmid': 159874377,
#    'name': 'Rua Dico Vieira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.61700000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18b9e8>}],
#  [1719599983,
#   1719600016,
#   {'osmid': 154896210,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 87.78}],
#  [1719599983,
#   1719599999,
#   {'osmid': 159874379,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.8}],
#  [1719599999,
#   1719600090,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 86.266}],
#  [1719599999,
#   1719600008,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 16.351}],
#  [1719599999,
#   1719599983,
#   {'osmid': 159874379,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.8}],
#  [1719600000,
#   1719599983,
#   {'osmid': 154896210,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 91.878}],
#  [1719600000,
#   1719600005,
#   {'osmid': 157801659,
#    'name': 'Rua Ademário Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 175.231}],
#  [1719600001,
#   1719600012,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 50.902}],
#  [1719600001,
#   1719600022,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 11.932}],
#  [1719600001,
#   1719600009,
#   {'osmid': 159874343,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.73100000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18ba58>}],
#  [1719600002,
#   1719600089,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 92.065}],
#  [1719600002,
#   1706461857,
#   {'osmid': 722087334,
#    'name': 'Rua João Padilha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.804}],
#  [1719600002,
#   1719600075,
#   {'osmid': 159874364,
#    'name': 'Rua João Padilha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.71400000000003,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18ba90>}],
#  [1719600002,
#   1426836626,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 88.146,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bac8>}],
#  [1719600003,
#   1719600020,
#   {'osmid': 159874340,
#    'name': 'Rua Blandina Castelo Branco',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 171.216}],
#  [1719600003,
#   1719600030,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 78.619}],
#  [1719600003,
#   1719600092,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 45.075}],
#  [1719600005,
#   1719600000,
#   {'osmid': 157801659,
#    'name': 'Rua Ademário Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 175.231}],
#  [1719600005,
#   1719600073,
#   {'osmid': 157801659,
#    'name': 'Rua Ademário Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 161.405}],
#  [1719600005,
#   1719600008,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 72.623}],
#  [1719600005,
#   1719600095,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 71.31}],
#  [1719600008,
#   1719599999,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 16.351}],
#  [1719600008,
#   1719600005,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 72.623}],
#  [1719600008,
#   1719600022,
#   {'osmid': 159874365,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 164.949,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bb00>}],
#  [1719600009,
#   1719383832,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 19.676}],
#  [1719600009,
#   1719383842,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 46.692}],
#  [1719600009,
#   1719600001,
#   {'osmid': 159874343,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.731,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bb38>}],
#  [1719600011,
#   1719383878,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 42.211}],
#  [1719600011,
#   1719383869,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 22.368}],
#  [1719600011,
#   1719600089,
#   {'osmid': 159874347,
#    'name': 'Rua Sílvio Leite',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.135,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bb70>}],
#  [1719600012,
#   1719600073,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 12.803}],
#  [1719600012,
#   1719600001,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 50.902}],
#  [1719600012,
#   1719383842,
#   {'osmid': 159874352,
#    'name': 'Rua Ademário Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 169.173,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bba8>}],
#  [1719600014,
#   1719600087,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 94.105}],
#  [1719600014,
#   1687960955,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 97.9}],
#  [1719600014,
#   1719600018,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.982}],
#  [1719600014,
#   1719600058,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 154.312}],
#  [1719600016,
#   1719600030,
#   {'osmid': 154896210,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 72.826}],
#  [1719600016,
#   1719600090,
#   {'osmid': 718506080,
#    'name': 'Rua Dico Veira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 168.108}],
#  [1719600018,
#   1426836650,
#   {'osmid': 156569528,
#    'oneway': False,
#    'name': 'Rua Atlas Catanhede',
#    'highway': 'residential',
#    'length': 96.254}],
#  [1719600018,
#   1687960975,
#   {'osmid': 156569528,
#    'oneway': False,
#    'name': 'Rua Atlas Catanhede',
#    'highway': 'residential',
#    'length': 25.199}],
#  [1719600018,
#   1719600014,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.982}],
#  [1719600020,
#   1719600003,
#   {'osmid': 159874340,
#    'name': 'Rua Blandina Castelo Branco',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 171.216}],
#  [1719600020,
#   1719600032,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 6.065}],
#  [1719600020,
#   1719600043,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.932}],
#  [1719600022,
#   1719600001,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 11.932}],
#  [1719600022,
#   1719599961,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 44.505}],
#  [1719600022,
#   1719600008,
#   {'osmid': 159874365,
#    'name': 'Rua Tia Joaca',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 164.949,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bc18>}],
#  [1719600024,
#   1700531325,
#   {'osmid': 345114754,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'length': 70.586}],
#  [1719600024,
#   1719600030,
#   {'osmid': 655068063,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 6.597}],
#  [1719600030,
#   1719600003,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 78.619}],
#  [1719600030,
#   1719600032,
#   {'osmid': 655068062,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 195.153}],
#  [1719600030,
#   1719600024,
#   {'osmid': 655068063,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 6.597}],
#  [1719600032,
#   1719600020,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 6.065}],
#  [1719600032,
#   1687960985,
#   {'osmid': 655068062,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 172.45999999999998,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bc50>}],
#  [1719600043,
#   1719600020,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.932}],
#  [1719600043,
#   1719600058,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.352}],
#  [1719600043,
#   1719600087,
#   {'osmid': 345120589,
#    'name': 'Rua Alzimiro Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 157.826}],
#  [1719600043,
#   1719600060,
#   {'osmid': 345120589,
#    'name': 'Rua Alzimiro Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 159.027}],
#  [1719600047,
#   1719383830,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 24.79}],
#  [1719600047,
#   1719383832,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 38.953}],
#  [1719600047,
#   1719599961,
#   {'osmid': 159874355,
#    'name': 'Rua Dona Cota Vieira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.482,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bc88>}],
#  [1719600050,
#   1719599965,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 92.507}],
#  [1719600050,
#   1719599976,
#   {'osmid': 159874378,
#    'name': 'Rua Izaac Cabral',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 118.813}],
#  [1719600050,
#   1719600093,
#   {'osmid': 719078559,
#    'name': 'Rua Izaac Cabral',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 148.729}],
#  [1719600050,
#   1719383735,
#   {'osmid': 722087332,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 135.357,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bcc0>}],
#  [1719600056,
#   1706461857,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.082}],
#  [1719600056,
#   1719600090,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 47.619}],
#  [1719600056,
#   1719600089,
#   {'osmid': 722068073,
#    'name': 'Rua Sílvio Leite',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 165.666}],
#  [1719600058,
#   1719600014,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 154.312}],
#  [1719600058,
#   1719600094,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 145.119}],
#  [1719600058,
#   1719600043,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.352}],
#  [1719600058,
#   1719599965,
#   {'osmid': 159874358,
#    'name': 'Rua Carlos Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 97.666}],
#  [1719600060,
#   1719600092,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 55.233}],
#  [1719600060,
#   1719600043,
#   {'osmid': 345120589,
#    'name': 'Rua Alzimiro Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 159.027}],
#  [1719600060,
#   1706461857,
#   {'osmid': 429917171,
#    'name': 'Rua Alzimiro Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 18.777}],
#  [1719600060,
#   1719600094,
#   {'osmid': 722087333,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 96.114}],
#  [1719600062,
#   1719600095,
#   {'osmid': 159841127,
#    'name': 'Rua Pastor Fernando Granjeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 162.178}],
#  [1719600062,
#   1719599981,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.12}],
#  [1719600062,
#   1719600073,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 58.085}],
#  [1719600062,
#   1719383806,
#   {'osmid': 159841127,
#    'name': 'Rua Pastor Fernando Granjeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.083,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bcf8>}],
#  [5273920644,
#   5273920648,
#   {'osmid': 545702027,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 143.179,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040e5c1d0>}],
#  [5273920644,
#   6804539287,
#   {'osmid': 545702027,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 1524.1630000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040e5c208>}],
#  [5273920644,
#   6792374612,
#   {'osmid': [738094185, 724267225],
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 1402.9610000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040e5c240>}],
#  [1719600073,
#   1719600005,
#   {'osmid': 157801659,
#    'name': 'Rua Ademário Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 161.405}],
#  [1719600073,
#   1719600062,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 58.085}],
#  [1719600073,
#   1719600012,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 12.803}],
#  [1719600075,
#   1719383752,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 12.275}],
#  [1719600075,
#   1719383878,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 52.575}],
#  [1719600075,
#   1719600002,
#   {'osmid': 159874364,
#    'name': 'Rua João Padilha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.714,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bd30>}],
#  [1719600077,
#   1719600000,
#   {'osmid': 154896210,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'maxspeed': '60',
#    'length': 90.285}],
#  [1719600077,
#   1719600095,
#   {'osmid': 159841127,
#    'name': 'Rua Pastor Fernando Granjeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 179.528}],
#  [1719600082,
#   1719383869,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 34.858}],
#  [1719600082,
#   1719383830,
#   {'osmid': 655067902,
#    'name': 'Avenida Princesa Isabel',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 31.588}],
#  [1719600082,
#   1719599978,
#   {'osmid': 159874377,
#    'name': 'Rua Dico Vieira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.61700000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bd68>}],
#  [1719600087,
#   1687960985,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 39.3}],
#  [1719600087,
#   1719600014,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 94.105}],
#  [1719600087,
#   1719600043,
#   {'osmid': 345120589,
#    'name': 'Rua Alzimiro Gomes da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 157.826}],
#  [1719600088,
#   1719600095,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 94.99}],
#  [1719600088,
#   1713309021,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 102.512}],
#  [1719600088,
#   1719599981,
#   {'osmid': 159841154,
#    'name': 'Rua Jorge Fraxe',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.797}],
#  [1719600088,
#   5121858393,
#   {'osmid': 159841154,
#    'name': 'Rua Jorge Fraxe',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 184.567,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18be10>}],
#  [1719600089,
#   1719599978,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 61.947}],
#  [1719600089,
#   1719600002,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 92.065}],
#  [1719600089,
#   1719600056,
#   {'osmid': 722068073,
#    'name': 'Rua Sílvio Leite',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 165.666}],
#  [1719600089,
#   1719600011,
#   {'osmid': 159874347,
#    'name': 'Rua Sílvio Leite',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.135,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18be48>}],
#  [1719600090,
#   1426836628,
#   {'osmid': 157801655,
#    'name': 'Rua Dico Veira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 165.881}],
#  [1719600090,
#   1719600056,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 47.619}],
#  [1719600090,
#   1719599999,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 86.266}],
#  [1719600090,
#   1719600016,
#   {'osmid': 718506080,
#    'name': 'Rua Dico Veira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 168.108}],
#  [1719600092,
#   1719600003,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 45.075}],
#  [1719600092,
#   1719600060,
#   {'osmid': 345120588,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 55.233}],
#  [1719600092,
#   1706461857,
#   {'osmid': 345120590,
#    'name': 'Rua João Padilha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 53.559}],
#  [1719600093,
#   1687960955,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 96.248}],
#  [1719600093,
#   1719600050,
#   {'osmid': 719078559,
#    'name': 'Rua Izaac Cabral',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 148.729}],
#  [1719600093,
#   1687960928,
#   {'osmid': 156569539,
#    'name': 'Rua Olavo Brasil Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.704,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bdd8>}],
#  [1719600094,
#   1719600058,
#   {'osmid': 159874338,
#    'name': 'Rua Dahas Abrahim',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 145.119}],
#  [1719600094,
#   1719600060,
#   {'osmid': 722087333,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 96.114}],
#  [1719600094,
#   1426836626,
#   {'osmid': 722087333,
#    'name': 'Rua Antônio Maciel',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 94.005}],
#  [1719600095,
#   1719600005,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 71.31}],
#  [1719600095,
#   1719600088,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 94.99}],
#  [1719600095,
#   1719600062,
#   {'osmid': 159841127,
#    'name': 'Rua Pastor Fernando Granjeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 162.178}],
#  [1719600095,
#   1719600077,
#   {'osmid': 159841127,
#    'name': 'Rua Pastor Fernando Granjeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 179.528}],
#  [6696469509,
#   5129422943,
#   {'osmid': 157801679,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 13.878}],
#  [6696469509,
#   5129422937,
#   {'osmid': 157801679,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 427.13000000000005,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f605e18bfd0>}],
#  [6696469509,
#   5129422950,
#   {'osmid': 527656350,
#    'oneway': False,
#    'highway': 'unclassified',
#    'length': 370.553,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b048>}],
#  [6894650395,
#   6894650396,
#   {'osmid': 736414853,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 110.827}],
#  [6894650395,
#   6894624177,
#   {'osmid': 738093731,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 67.694}],
#  [6894650395,
#   6894528602,
#   {'osmid': 738093731,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 258.498,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b198>}],
#  [6894650396,
#   6894650395,
#   {'osmid': 736414853,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 110.827}],
#  [6894650396,
#   6894650389,
#   {'osmid': [738093898, 736414852],
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 413.9510000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b1d0>}],
#  [6894650396,
#   6894528997,
#   {'osmid': 736414852,
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 214.857,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b208>}],
#  [321520743,
#   6947307079,
#   {'osmid': 392879710,
#    'name': 'Rua Alfredo Cruz',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 16.746}],
#  [321520743,
#   321519672,
#   {'osmid': 154903789,
#    'oneway': True,
#    'lanes': '2',
#    'name': 'Avenida Capitão Júlio Bezerra',
#    'highway': 'secondary',
#    'length': 152.141,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b3c8>}],
#  [321520743,
#   1067749186,
#   {'osmid': 392879710,
#    'name': 'Rua Alfredo Cruz',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 84.461,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b400>}],
#  [321520744,
#   1710049674,
#   {'osmid': 29231449,
#    'oneway': True,
#    'name': 'Avenida Capitão Júlio Bezerra',
#    'highway': 'secondary',
#    'length': 141.019,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b438>}],
#  [321520744,
#   3182709571,
#   {'osmid': 368957875,
#    'highway': 'secondary',
#    'junction': 'roundabout',
#    'oneway': True,
#    'length': 18.243,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b470>}],
#  [6770787536,
#   1724053959,
#   {'osmid': 160355820,
#    'name': 'Rua Marte',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 90.852}],
#  [6770787536,
#   1724053761,
#   {'osmid': 160355820,
#    'name': 'Rua Marte',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 209.329,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b518>}],
#  [6770787536,
#   1724053822,
#   {'osmid': 160355831,
#    'name': 'Rua Ursa Maior',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 86.781,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f9b550>}],
#  [3270903035,
#   3270763243,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 78.872}],
#  [3270903035,
#   5057468198,
#   {'osmid': 529714689,
#    'oneway': True,
#    'name': 'Avenida Equador',
#    'highway': 'tertiary',
#    'length': 12.26}],
#  [3270903036,
#   5057468192,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 77.745}],
#  [3270903036,
#   3270894435,
#   {'osmid': 320547673,
#    'name': 'Rua Natal',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 268.498}],
#  [3270903036,
#   5057468197,
#   {'osmid': 320547673,
#    'name': 'Rua Natal',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 13.331}],
#  [3270903037,
#   3270903036,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 79.654}],
#  [3270903037,
#   3270894436,
#   {'osmid': 320538626,
#    'name': 'Rua Junco do Seridó',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 266.801}],
#  [3270903037,
#   5057468196,
#   {'osmid': 320538626,
#    'name': 'Rua Junco do Seridó',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 14.225}],
#  [3270903038,
#   3270903037,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 80.44}],
#  [3270903038,
#   3270894437,
#   {'osmid': 518473187,
#    'name': 'Rua Jucurutú',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 266.828}],
#  [3270903038,
#   5057468195,
#   {'osmid': 518473187,
#    'name': 'Rua Jucurutú',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 12.594}],
#  [3270903039,
#   3270903038,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 75.745}],
#  [3270903039,
#   3270894438,
#   {'osmid': 320538625,
#    'name': 'Rua São José de Seridó',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 265.757}],
#  [3270903039,
#   5057468194,
#   {'osmid': 320538625,
#    'name': 'Rua São José de Seridó',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 13.07}],
#  [6908347658,
#   6168255617,
#   {'osmid': 658727595,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 10.173}],
#  [6908347659,
#   5000993389,
#   {'osmid': 511187843,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 7.377}],
#  [1713308948,
#   1706461846,
#   {'osmid': 159237686,
#    'name': 'Rua Maria Rodrigues dos Santos',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 199.996}],
#  [1713308948,
#   1713309016,
#   {'osmid': 655086391,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'length': 96.666}],
#  [1713308951,
#   1713308972,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 98.672}],
#  [1713308951,
#   6951307008,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 11.67}],
#  [1713308951,
#   1713309002,
#   {'osmid': 742500471,
#    'name': 'Rua Francisco Custódio de Andrade',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.784}],
#  [1713308953,
#   4285277775,
#   {'osmid': 156357721,
#    'name': 'Avenida Nossa Senhora de Nazaré',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 149.176}],
#  [1713308953,
#   1713309021,
#   {'osmid': 156357721,
#    'name': 'Avenida Nossa Senhora de Nazaré',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 170.562}],
#  [1713308953,
#   6951307008,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 90.793}],
#  [1713308953,
#   1719599981,
#   {'osmid': 718506079,
#    'name': 'Rua América Sarmento Ribeiro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 102.787}],
#  [1713308959,
#   1713308967,
#   {'osmid': 159237676,
#    'name': 'Rua Belarmino Fernandes Magalhães',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 201.748}],
#  [1713308959,
#   1719760200,
#   {'osmid': 159237676,
#    'name': 'Rua Belarmino Fernandes Magalhães',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 8.699}],
#  [1713308959,
#   1713308948,
#   {'osmid': 655086391,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'length': 92.776}],
#  [1713308963,
#   1713309021,
#   {'osmid': 156357721,
#    'name': 'Avenida Nossa Senhora de Nazaré',
#    'highway': 'secondary',
#    'oneway': False,
#    'length': 187.132}],
#  [1713308963,
#   1934377594,
#   {'osmid': 655068064,
#    'oneway': True,
#    'name': 'Avenida Carlos Pereira de Melo',
#    'highway': 'secondary',
#    'length': 82.113}],
#  [1713308967,
#   1706461846,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 96.947}],
#  [1713308967,
#   1713308996,
#   {'osmid': 158453935,
#    'name': 'Rua Júlio Pinto',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 95.046}],
#  [1713308967,
#   1713309005,
#   {'osmid': 159237676,
#    'name': 'Rua Belarmino Fernandes Magalhães',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 167.917}],
#  [1713308967,
#   1713308959,
#   {'osmid': 159237676,
#    'name': 'Rua Belarmino Fernandes Magalhães',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 201.748}],
#  [1713308972,
#   4288088277,
#   {'osmid': 159237696,
#    'name': 'Rua Lindolfo Bernardo Coltinho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 53.329}],
#  [1713308972,
#   1713309012,
#   {'osmid': 159237696,
#    'name': 'Rua Lindolfo Bernardo Coltinho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 166.445}],
#  [1713308972,
#   1713309009,
#   {'osmid': 718506079,
# ...
#  [1700531501,
#   1700531514,
#   {'osmid': 159877449,
#    'oneway': False,
#    'name': 'Rua Elza Mesquita da Silva',
#    'highway': 'residential',
#    'length': 175.633}],
#  [1700531501,
#   1700531439,
#   {'osmid': 156570903,
#    'oneway': False,
#    'name': 'Rua Deco Fonteles',
#    'highway': 'secondary',
#    'length': 76.44600000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f53d30>}],
#  [1700531502,
#   1700531474,
#   {'osmid': 157801692,
#    'name': 'Rua Olívia Paixão da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 212.173}],
#  [1700531502,
#   1700531438,
#   {'osmid': 157801692,
#    'name': 'Rua Olívia Paixão da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 89.521}],
#  [1700531502,
#   1700531464,
#   {'osmid': 159874344,
#    'name': 'Rua Severino Caetano da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 163.183}],
#  [1700531502,
#   1700531325,
#   {'osmid': 159874344,
#    'name': 'Rua Severino Caetano da Silva',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 170.906}],
#  [1700531504,
#   1700531470,
#   {'osmid': 157801632,
#    'oneway': False,
#    'ref': 'BR-174',
#    'name': 'Rua 2 de Julho',
#    'highway': 'residential',
#    'length': 158.396}],
#  [1700531504,
#   2103405599,
#   {'osmid': 157801632,
#    'oneway': False,
#    'ref': 'BR-174',
#    'name': 'Rua 2 de Julho',
#    'highway': 'residential',
#    'length': 168.393}],
#  [1700531504,
#   1700531512,
#   {'osmid': 157801694,
#    'oneway': False,
#    'name': 'Rua Domingos Ferreira dos Reis',
#    'highway': 'residential',
#    'length': 76.627}],
#  [1700531504,
#   2103405594,
#   {'osmid': [489431174, 157801694],
#    'oneway': False,
#    'name': ['Rua Domingos Ferreira dos Reis', 'Rua 06'],
#    'highway': 'residential',
#    'length': 243.761,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f53da0>}],
#  [1700531510,
#   1700531456,
#   {'osmid': 157801696,
#    'oneway': False,
#    'name': 'Rua Miró Bessa Lima',
#    'highway': 'residential',
#    'length': 95.036}],
#  [1700531510,
#   1700531439,
#   {'osmid': 157801696,
#    'oneway': False,
#    'name': 'Rua Miró Bessa Lima',
#    'highway': 'residential',
#    'length': 174.329}],
#  [1700531510,
#   1700531514,
#   {'osmid': 159877448,
#    'name': 'Rua Oder Brasil',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 80.995}],
#  [1700531510,
#   1700531436,
#   {'osmid': 159877448,
#    'name': 'Rua Oder Brasil',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 78.482}],
#  [1700531512,
#   1700531504,
#   {'osmid': 157801694,
#    'oneway': False,
#    'name': 'Rua Domingos Ferreira dos Reis',
#    'highway': 'residential',
#    'length': 76.627}],
#  [1700531512,
#   1700531399,
#   {'osmid': 383065260,
#    'oneway': False,
#    'name': 'Rua Pinto Martins',
#    'highway': 'residential',
#    'length': 155.256}],
#  [1700531512,
#   2103405591,
#   {'osmid': 719076544,
#    'oneway': False,
#    'name': 'Rua Pinto Martins',
#    'highway': 'residential',
#    'length': 167.067}],
#  [1700531512,
#   1700531368,
#   {'osmid': 719076545,
#    'oneway': False,
#    'name': 'Rua Domingos Ferreira dos Reis',
#    'highway': 'residential',
#    'length': 72.405}],
#  [1700531513,
#   1700531482,
#   {'osmid': 156570904,
#    'oneway': False,
#    'name': 'Rua Soldado da Polícia Militar Django da Silva',
#    'highway': 'residential',
#    'length': 11.79}],
#  [1700531513,
#   1719684182,
#   {'osmid': 182195668,
#    'oneway': True,
#    'name': 'Avenida Parimé Brasil',
#    'highway': 'secondary',
#    'length': 101.319}],
#  [1700531513,
#   1700531423,
#   {'osmid': 156570904,
#    'oneway': False,
#    'name': 'Rua Soldado da Polícia Militar Django da Silva',
#    'highway': 'residential',
#    'length': 211.19700000000003,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f53e80>}],
#  [1700531514,
#   1700531510,
#   {'osmid': 159877448,
#    'name': 'Rua Oder Brasil',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 80.995}],
#  [1700531514,
#   1700531501,
#   {'osmid': 159877449,
#    'oneway': False,
#    'name': 'Rua Elza Mesquita da Silva',
#    'highway': 'residential',
#    'length': 175.633}],
#  [1700531514,
#   1700531474,
#   {'osmid': 159877449,
#    'oneway': False,
#    'name': 'Rua Elza Mesquita da Silva',
#    'highway': 'residential',
#    'length': 79.742}],
#  [3270763236,
#   3270763240,
#   {'osmid': 320547676,
#    'oneway': True,
#    'name': 'Avenida Caicó',
#    'highway': 'residential',
#    'length': 52.996}],
#  [3270763236,
#   3518106630,
#   {'osmid': 518473187,
#    'name': 'Rua Jucurutú',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 280.407}],
#  [3270763238,
#   3518106635,
#   {'osmid': 320546972,
#    'name': 'Rua Parelhas',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 277.127}],
#  [3270763238,
#   3270763372,
#   {'osmid': 518474487,
#    'oneway': True,
#    'name': 'Avenida Caicó',
#    'highway': 'residential',
#    'length': 77.848}],
#  [1722140232,
#   1722140127,
#   {'osmid': 129300429,
#    'name': 'Rua Rosa Oliveira de Araújo',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 72.415}],
#  [1722140232,
#   1721143784,
#   {'osmid': 129300429,
#    'name': 'Rua Rosa Oliveira de Araújo',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 65.539}],
#  [1722140232,
#   2103387202,
#   {'osmid': 160142621,
#    'name': 'Rua Angela Evelim Coelho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 151.048}],
#  [1722140232,
#   1722140255,
#   {'osmid': 160142621,
#    'name': 'Rua Angela Evelim Coelho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 151.578}],
#  [3270763240,
#   3518106629,
#   {'osmid': 518473190,
#    'name': 'Rua Lagoa Nova',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 285.272}],
#  [3270763240,
#   5057487222,
#   {'osmid': 518474535,
#    'name': 'Rua Lagoa Nova',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 11.009}],
#  [1701121449,
#   1701121452,
#   {'osmid': 395789813,
#    'oneway': True,
#    'name': 'Avenida Nossa Senhora da Consolata',
#    'highway': 'tertiary',
#    'length': 133.01500000000001,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61908>}],
#  [1701121449,
#   3648084755,
#   {'osmid': 530834354,
#    'name': 'Avenida Nossa Senhora da Consolata',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 69.02799999999999,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61940>}],
#  [1701121452,
#   1701121449,
#   {'osmid': 395789817,
#    'oneway': True,
#    'name': 'Avenida Nossa Senhora da Consolata',
#    'highway': 'tertiary',
#    'length': 129.335,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61978>}],
#  [1701121452,
#   6948990049,
#   {'osmid': 530834356,
#    'name': 'Avenida Nossa Senhora da Consolata',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 46.888,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f619b0>}],
#  [1723338161,
#   1723356951,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 79.344}],
#  [1723338161,
#   1723338196,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 81.979}],
#  [1723338161,
#   1723326974,
#   {'osmid': 160280992,
#    'name': 'Rua Rio Claro',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 147.815}],
#  [1722140236,
#   1723305093,
#   {'osmid': 160142627,
#    'name': 'Rua Lua Nova',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 58.353}],
#  [1722140236,
#   1723280141,
#   {'osmid': 160276501,
#    'name': 'Rua Estrela do Norte',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 81.88}],
#  [1722140236,
#   1723280155,
#   {'osmid': 160276501,
#    'name': 'Rua Estrela do Norte',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 102.594}],
#  [1722140236,
#   1722140205,
#   {'osmid': 160273210,
#    'name': 'Rua Elifas Levi Veloso Filho',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 658.062,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040d7e4a8>}],
#  [1723338174,
#   1723338197,
#   {'osmid': 160279254,
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': 'Rua Parque Industrial',
#    'highway': 'tertiary',
#    'junction': 'roundabout',
#    'length': 13.295,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61be0>}],
#  [3270763246,
#   3270769762,
#   {'osmid': 320538621,
#    'oneway': True,
#    'name': 'Avenida Jardim do Seridó',
#    'highway': 'residential',
#    'length': 116.253}],
#  [3270763246,
#   3270894431,
#   {'osmid': 320546973,
#    'name': 'Rua Jardim de Piranhas',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 266.005}],
#  [3270763246,
#   6798857040,
#   {'osmid': 320546973,
#    'name': 'Rua Jardim de Piranhas',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 12.248}],
#  [4303556035,
#   1723338217,
#   {'osmid': 655620757,
#    'oneway': True,
#    'lanes': '2',
#    'ref': 'BR-174',
#    'name': 'Avenida Brasil',
#    'highway': 'primary',
#    'maxspeed': '60',
#    'length': 89.784}],
#  [4303556036,
#   1723327019,
#   {'osmid': 431108567,
#    'oneway': True,
#    'name': 'Avenida Rio São Francisco',
#    'highway': 'tertiary',
#    'length': 39.454}],
#  [4303556036,
#   4303556035,
#   {'osmid': 655620757,
#    'oneway': True,
#    'lanes': '2',
#    'ref': 'BR-174',
#    'name': 'Avenida Brasil',
#    'highway': 'primary',
#    'maxspeed': '60',
#    'length': 10.149}],
#  [1723338181,
#   4419262250,
#   {'osmid': 156362754,
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': 'Avenida Brasil',
#    'highway': 'primary_link',
#    'length': 150.16599999999997,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61c50>}],
#  [1723338181,
#   1723327053,
#   {'osmid': 160279260,
#    'name': 'Rua Estrela Celeste',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 168.659,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61c88>}],
#  [4303556037,
#   6947905028,
#   {'osmid': 157802812,
#    'oneway': False,
#    'name': 'Rua Floriano Peixoto',
#    'highway': 'tertiary',
#    'length': 9.355,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61cc0>}],
#  [4303556037,
#   6945912809,
#   {'osmid': 157802812,
#    'oneway': False,
#    'name': 'Rua Floriano Peixoto',
#    'highway': 'tertiary',
#    'length': 68.196,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f61cf8>}],
#  [1723338196,
#   1723338161,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 81.979}],
#  [1723338196,
#   1723326956,
#   {'osmid': 160280972,
#    'name': 'Rua Rio Tapajós',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 147.724}],
#  [1723338196,
#   1723326930,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 198.71200000000002,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e128>}],
#  [1723338197,
#   1686177362,
#   {'osmid': 160279254,
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': 'Rua Parque Industrial',
#    'highway': 'tertiary',
#    'junction': 'roundabout',
#    'length': 14.635,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e160>}],
#  [1723338197,
#   1686177317,
#   {'osmid': 160279257,
#    'oneway': True,
#    'ref': 'BR-174',
#    'highway': 'tertiary',
#    'length': 52.039,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e198>}],
#  [1723338203,
#   1723356941,
#   {'osmid': 160276528,
#    'name': 'Rua Arco-Íris',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 21.399}],
#  [1723338203,
#   1723356990,
#   {'osmid': 160276528,
#    'name': 'Rua Arco-Íris',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 146.226}],
#  [1723338203,
#   1723338227,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 77.71}],
#  [1722140245,
#   4301261474,
#   {'osmid': 430862601,
#    'name': 'Travessa Cézar Nogueira Júnior',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 188.467}],
#  [1722140245,
#   1912882670,
#   {'osmid': 431279386,
#    'name': 'Rua Cézar Nogueira Júnior',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 761.718,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040d7e5c0>}],
#  [1722140245,
#   6270810679,
#   {'osmid': 431279386,
#    'name': 'Rua Cézar Nogueira Júnior',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 420.181,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040d7e5f8>}],
#  [1723338206,
#   1723357159,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 80.532}],
#  [1723338206,
#   1723356970,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 77.032}],
#  [1723338206,
#   1723357018,
#   {'osmid': 160280966,
#    'name': 'Rua Estrela Bonita',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 144.899,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e2e8>}],
#  [4562357728,
#   1710572039,
#   {'osmid': 161262530,
#    'oneway': True,
#    'name': 'Rua Pau-Rainha',
#    'highway': 'unclassified',
#    'length': 88.099}],
#  [4562357728,
#   4562357729,
#   {'osmid': 460609632,
#    'name': 'Travessa Pau-Rainha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 210.904}],
#  [4562357729,
#   4562357728,
#   {'osmid': 460609632,
#    'name': 'Travessa Pau-Rainha',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 210.904}],
#  [4562357729,
#   1710571979,
#   {'osmid': 740995993,
#    'oneway': True,
#    'name': 'Rua Dionísio Brito de Araújo',
#    'highway': 'tertiary',
#    'length': 80.209}],
#  [1722140247,
#   1722140207,
#   {'osmid': 129300422,
#    'oneway': False,
#    'name': 'Rua Cidade Cascavel',
#    'highway': 'residential',
#    'length': 149.475}],
#  [1722140247,
#   1722140222,
#   {'osmid': 129300422,
#    'oneway': False,
#    'name': 'Rua Cidade Cascavel',
#    'highway': 'residential',
#    'length': 177.302}],
#  [1722140247,
#   1722140137,
#   {'osmid': 655699516,
#    'name': 'Rua Francisco Sales Veira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 82.338}],
#  [1722140247,
#   1722140181,
#   {'osmid': 655699516,
#    'name': 'Rua Francisco Sales Veira',
#    'highway': 'residential',
#    'oneway': False,
#    'length': 82.527}],
#  [1723338215,
#   6804554185,
#   {'osmid': 725731036,
#    'name': 'Rua Parque Industrial',
#    'highway': 'tertiary',
#    'oneway': False,
#    'length': 10.919}],
#  [1723338215,
#   6641405100,
#   {'osmid': 344849387,
#    'name': 'Rua Parque Industrial',
#    'highway': 'unclassified',
#    'oneway': False,
#    'length': 423.613,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e400>}],
#  [1723338215,
#   6804465917,
#   {'osmid': [725748792, 725722903],
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': ['Rua Parque Industrial', 'Rua Alexandre Barbosa Monteiro'],
#    'highway': 'residential',
#    'length': 252.503,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e4a8>}],
#  [1723338217,
#   5064543861,
#   {'osmid': 655628064,
#    'oneway': True,
#    'lanes': '2',
#    'ref': 'BR-174',
#    'name': 'Avenida Brasil',
#    'highway': 'primary',
#    'maxspeed': '60',
#    'length': 15.915}],
#  [1723338217,
#   1723327108,
#   {'osmid': 160279256,
#    'oneway': True,
#    'name': 'Rua Campinas',
#    'highway': 'tertiary',
#    'length': 33.088,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e4e0>}],
#  [1723338227,
#   1723338203,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 77.71}],
#  [1723338227,
#   1913135149,
#   {'osmid': 160279259,
#    'highway': 'residential',
#    'oneway': False,
#    'length': 87.199,
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e630>}],
#  [1723338227,
#   1723357035,
#   {'osmid': [160280955, 160280983],
#    'highway': 'residential',
#    'oneway': False,
#    'length': 150.478,
#    'name': 'Rua Universo',
#    'geometry': <shapely.geometry.linestring.LineString at 0x7f6040f6e668>}],
#  [1723338231,
#   6936400248,
#   {'osmid': 382471916,
#    'oneway': True,
#    'name': 'Avenida das Industrias',
#    'highway': 'tertiary',
#    'length': 119.916}],
#  [1723338231,
#   4419262264,
#   {'osmid': 740873937,
#    'oneway': True,
#    'ref': 'BR-174',
#    'name': 'Rua Parque Industrial',
#    'highway': 'tertiary',
#    'length': 9.494}],
#  ...]

# %% [markdown]
# # Gera uma lista com as pontuações que cada aresta recebeu dentre as suas características

# %%
listaValores = []
valorRuim = -1

for i in listaDados:
    soma = 0
    #print(i[2]['osmid'])    
    
    #---------------------------------------------------------------------------------------------------------            
    '''
    if 'maxspeed' in i[2] and isinstance( i[2]['maxspeed'], int ):
        if int(i[2]['maxspeed']) < 40 and int(i[2]['maxspeed']) > 60 or 'maxspeed' not in i[2]:
            soma = valorRuim
        else:
            soma += 5
    else:
        if 'maxspeed' in i[2]:
            p = 0
            j = 0
            for k in i[2]['maxspeed']:
                p += int(k)
                j+=1
            soma += (p/j)
        else:
            soma = valorRuim
    '''
    
    #---------------------------------------------------------------------------------------------------------
    if "highway" in i[2]:
        if i[2]['highway'] == "residential": #ex Rua Chicó Lira
            soma = valorRuim
        elif i[2]['highway'] == "primary": #ex: avenida venezuela
            soma = 1
        elif i[2]['highway'] == "secondary": #ex: Major Williams
            soma = 1
        elif i[2]['highway'] == "tertiary": #ex: Rua General Penha Brasil
            soma = 1
        else:
            soma = valorRuim
    
    
    #---------------------------------------------------------------------------------------------------------    
    #total de faixas da via
    '''
    if ("lanes" in i[2]) and ("oneway" in i[2]):
        liness = i[2]['lanes']
        if isinstance(liness , list):
            for d in liness:
                soma += int(d)
        else:
            soma = (int(liness) * 5) + 5 + soma
    else:
        
        if "lanes" in i[2]:
            soma +=  int(i[2]['lanes']) * 5
            
        #o resultado da maioria
        if "oneway" in i[2]:
            if i[2]['oneway'] == True:
                soma += 5                
            else:
                soma = valorRuim
    '''
    
    listaValores.append(soma)

# %% [markdown]
# # Separa os vértices que não conseguiram atingir a pontuação mínima para remoção do Grafo

# %%
remover = []

for i in range(len(listaValores)):
    #if listaValores[i] <= 0:
    if listaValores[i] <= removerPior:
        remover.append( (listaDados[i][0], listaDados[i][1]))
        
#remove as arestas que foram selecionadas como ruins 
G.remove_edges_from(remover)

# %% [markdown]
# # Atualiza a lista de arestas que estão aptas a serem selecionadas

# %%
listaValoresNew = []
listaDadosNew = []

for i in range(len(listaDados)):
    if listaValores[i] >= removerPior:
        listaValoresNew.append( listaValores[i] )
        listaDadosNew.append( listaDados[i] )

#remover os dados antigos para devolver memória
listaDados.clear()
listaValores.clear()
print(len(listaValoresNew))
# Out:
# 7049

# %%
'''
    Acesso aos dados!

print(listaDadosNew[0])
print()
print(listaDadosNew[0][0])
print()
print(listaDadosNew[0][1])
print()
print(listaDadosNew[0][2])
print()
print(listaDadosNew[0][2]['name'])
'''
# Out:
# "\n    Acesso aos dados!\n\nprint(listaDadosNew[0])\nprint()\nprint(listaDadosNew[0][0])\nprint()\nprint(listaDadosNew[0][1])\nprint()\nprint(listaDadosNew[0][2])\nprint()\nprint(listaDadosNew[0][2]['name'])\n"

# %%
ox.plot_graph(G, fig_height=fig_height, fig_width=fig_width, edge_color=edge_color, bgcolor=bgcolor, node_color=node_color, node_size=node_size, filename="mapaFiltrado", save=True,  file_format=formato_imgs)
# Out:
# (<Figure size 1440x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f605e03ecc0>)

# %% [markdown]
# # Lista que receberá os caminhos encontrados pelo AG

# %%
listaResultadoDFS = []
tamanhoDosCiclosSalvos = []

tamGenes = len( listaDadosNew )

# %% [markdown]
# # Lista para salvar as informações da evolução do AG para plotagem de gráfico ao final do experimento

# %%
PlotMinDadosONEMAX  = []
PlotMeanDadosONEMAX = []
PlotMaxDadosONEMAX  = []

PlotMinDadosDFS  = []
PlotMeanDadosDFS = []
PlotMaxDadosDFS  = []

PlotMinDistDFS = []
PlotMeanDistDFS = []
PlotMaxDistDFS = []

PlotMinTamCiclo = []
PlotMeanTamCiclo = []
PlotMaxTamCiclo = []

PlotMinDistCiclo = []
PlotMeanDistCiclo = []
PlotMaxDistCiclo = []

PlotTempoExecucao = []

# %% [markdown]
# # Controle dos ciclos

# %%
PlotMaioresCiclos = []
PlotMaioresCiclos.append(0)

# %%
lenghtListaDadosnew = len(listaDadosNew)

# %% [markdown]
# # Reforço

# %%
reforco = [ 0 for _ in range(0, len(G.nodes)+1)]

# %% [markdown]
# # Busca em profundidade que encontrará os caminhos caso exista

# %%
def DFS_BuscaCiclo(grafo, mapa, mapaGrafo, verticeInicial, tamGrafo):
    
    import stack    
    pilha = stack.stack()
    v = verticeInicial
    
    #vetor de marcação de visitados e de elementos que estão na pilha O(1)
    visitados = []
    pilha_rec = []
    
    for i in range(tamGrafo):
        visitados.append(False)
        pilha_rec.append(False)
    
        
    it = -1
    contListaPercorrida = 0
    contDistPercorrida  = 0
    semDistancia = 0
    listaPercorrida = []
    controleMaiorCiclo = PlotMaioresCiclos[-1]
    
    tamanhoCicloRetorno = 0
    distanciaCicloRetorno = 0
    
    #inicio da BFS
    while True:
        achou_vizinho = False        
        
        listaPercorrida.append(v)
        contListaPercorrida += 1
                
        if not visitados[ mapa[ v ] ]:
            x = mapa[ v ]
            
            pilha.empilhar( x )
            visitados[ x ] = True
            pilha_rec[ x ] = True
            
            
        for it in grafo[v]:
            
            #se tiver na pilha é porque possue ciclo - Achou um Ciclo          
            if pilha_rec[ mapa[ it ] ] and it == verticeInicial:
                
                listaArestasCiclo = []
                
                for k in listaPercorrida:
                    if pilha_rec[ mapa[ k ] ] == True:
                        listaArestasCiclo.append( k )
                        
                tamList = len( listaArestasCiclo )
                
                tamanhoCicloRetorno = tamList
                distanciaCicloRetorno = contDistPercorrida
                
                '''
                    sempre salva ciclos maiores!
                '''
                if tamList > controleMaiorCiclo:
                    controleMaiorCiclo = tamList
                    
                    PlotMaioresCiclos.append( controleMaiorCiclo )
                                                        
                    '''
                        Pega o ciclo para salvar
                    '''
                    
                    cicloAtual = []
                    
                    #for k in range(1, len(listaArestasCiclo)):
                    for k in range(1, tamList):
                        cicloAtual.append( (listaArestasCiclo[k-1], listaArestasCiclo[k]) )
                    cicloAtual.append( ( listaArestasCiclo[-1], listaArestasCiclo[0] ) )
                    
                    cicloAtualList = list( cicloAtual )
                    listaResultadoDFS.append( cicloAtualList )
                    tamanhoDosCiclosSalvos.append( tamList )
                    
                else:
                    achou_vizinho = False
                    break
                
                    
            if not visitados[ mapa[ it ] ]:
                achou_vizinho = True
                break
                
        if not achou_vizinho:
            pilha_rec[ pilha.topo() ] = False
                
            pilha.desempilhar()
            
            if pilha.p_vazia():
                break
                
            v = mapaGrafo[ pilha.topo() ]
        
        else:
            # -------- pegar a distancia de A -> B ---------
            # do vertice A
            verticeAtual = v
            # para o vertice B
            verticeNovo  = it
            
            '''
            print(listaDadosNew[0])
            print()
            print(listaDadosNew[0][0])
            print()
            print(listaDadosNew[0][1])
            print()
            print(listaDadosNew[0][2])
            print()
            print(listaDadosNew[0][2]['name'])

            [321519672, 3589971255, {'osmid': 704201746, 'oneway': True, 'name': 'Rua Coronel Pinto', 'highway': 'tertiary', 'length': 18.205}]

            321519672

            3589971255

            {'osmid': 704201746, 'oneway': True, 'name': 'Rua Coronel Pinto', 'highway': 'tertiary',
            'length': 18.205}

            Rua Coronel Pinto

            '''
            try:

                '''
                    Pegar a distancia percorrida pela DFS..
                '''
                            
                for lista_i in range(lenghtListaDadosnew):            
                    if( listaDadosNew[lista_i][0] == verticeAtual and listaDadosNew[lista_i][1] == verticeNovo ):

                        if 'length' in listaDadosNew[lista_i][2]:
                            lenghtAresta = float(listaDadosNew[lista_i][2]['length'])
                            contDistPercorrida  = float(contDistPercorrida + lenghtAresta)
                        else:
                            semDistancia = semDistancia + 1
            except:
                print("Erro na distancia...")
            
            
            
            # ---------------------------------------------
            
            # da busca em profundidade troca o vertice para o proximo
            # ---- NAO mexer ----------
            v =  it
            # -------------------------
    
    '''
        calcular a distancia achada + a media das distancias nao achadas
    '''
    
    
    # distancia percorrida
    distanciaFinal = ( contDistPercorrida ) + ( 15 * semDistancia )
    #print("Distancia percorrida: {}".format(distanciaFinal))   
    
    '''
        Falta retornar a distancia percorrida junto com a contListaPercorrida
    '''
    
    # Retorna a quantidade de arestas visitadas na busca em profundidade
    return contListaPercorrida, distanciaFinal, tamanhoCicloRetorno, distanciaCicloRetorno

# %% [markdown]
# # Função que executa um filtro para remover as arestas não selecionadas pelo AG e envia a DFS para validação de rotas

# %%
def temCicloDFS(individuo):
    
    # cópia do grafo
    G_aux = G.copy()
    
    tamNodes = len(G_aux.nodes)
    
        
    # ajuda na evolução do onemax
    if recebeAjuda == True:        
        for i in range(ajudaQtd):            
            #posicao = random.randint(0,tam-1)
            #individuo[posicao] = 1
            individuo[random.randint(0, tamGenes-1)] = 1
    
    
    ## Aprendizagem por reforço
    if reforco == True:
        for i in range(0, tamInd):
            if individuo[i] == 0 and reforco[i] > 0:
                individuo[i] = 1
        
                
    #identificador da posicao do nodo centro cívico para verificar se esta ativo
    for i in range(tamGenes):
        if listaDadosNew[i][0] == nodosCentroCivico[0] and listaDadosNew[i][1] == nodosCentroCivico[1]:
            individuo[i] = 1            
            break;
            
    
    #lista para remover os nós não selecionados pelo AG
    listaRemover = []            
        
    #Seleção dos nodos não selecionados
    #for i in range(len(individuo)):
    for i in range(tamGenes):
        if individuo[i] == 0:
            listaRemover.append( (listaDadosNew[i][0], listaDadosNew[i][1]) )            
        
        
    #Remove os nodos não selecionados pelo AG
    G_aux.remove_edges_from( listaRemover )
    
    
    
    #listaMapa recebe os valores de [0 a totNodos]
    listaMapa = []
    #for i in range(len(G_aux.nodes)):
    for i in range(tamNodes):
        listaMapa.append(i)
    
    
    # 215151515 --> 10
    mapa = pd.Series(index=G_aux.nodes, data=listaMapa)
    # 10 --> 215151515
    mapaGrafo = pd.Series(G_aux.nodes)
    
    
    '''
        DFS --- Busca um ciclo a partir do terminal de ônibus do centro Cívico 
    
    '''
       
    return DFS_BuscaCiclo(G_aux, mapa, mapaGrafo, nodosCentroCivico[0], len(G_aux.nodes))

# %%
#feature 1

def calc_objetivo_1(id, l_onemax):
    minimo = int(np.min(l_onemax))
    maximo = int(np.max(l_onemax))
    media  = int(np.mean(l_onemax))
    #print("ONEMAX:\t{}\t{}\t{}".format(minimo,media , maximo))
    PlotMinDadosONEMAX.append(minimo)
    PlotMeanDadosONEMAX.append(media)
    PlotMaxDadosONEMAX.append(maximo)

# %%
#feature 2

def calc_objetivo_2(id, l_dfs):
    minimo = int(np.min(l_dfs))
    maximo = int(np.max(l_dfs))
    media  = int(np.mean(l_dfs))
    #print("DFS:\t{}\t{}\t{}".format(minimo,media , maximo))
    # Grafico
    PlotMinDadosDFS.append(minimo)
    PlotMeanDadosDFS.append(media)
    PlotMaxDadosDFS.append(maximo)

# %%
#feature 3

def calc_objetivo_3(id, l_dist):
    minimo = int(np.min(l_dist))
    maximo = int(np.max(l_dist))
    media  = int(np.mean(l_dist))
    #print("DIST:\t{}\t{}\t{}".format(minimo,media , maximo))
    # Grafico
    PlotMinDistDFS.append(minimo)
    PlotMeanDistDFS.append(media)
    PlotMaxDistDFS.append(maximo)

# %%
#feature 4

def calc_objetivo_4(id, l_tam_ciclo):
    minimo = int(np.min(l_tam_ciclo))
    maximo = int(np.max(l_tam_ciclo))
    media  = int(np.mean(l_tam_ciclo))
    #print("TamC:\t{}\t{}\t{}".format(minimo,media , maximo))
    # Grafico
    PlotMinTamCiclo.append(minimo)
    PlotMeanTamCiclo.append(media)
    PlotMaxTamCiclo.append(maximo)

# %%
#feature 5

def calc_objetivo_5(id, l_dist_ciclo):
    minimo = int(np.min(l_dist_ciclo))
    maximo = int(np.max(l_dist_ciclo))
    media  = int(np.mean(l_dist_ciclo))
    #print("DistRotaC:\t{}\t{}\t{}".format(minimo,media , maximo))
    # Grafico
    PlotMinDistCiclo.append(minimo)
    PlotMeanDistCiclo.append(media)
    PlotMaxDistCiclo.append(maximo)

# %%
def timeExecuteGeneration(tempoInicio):
    tempoFinal = time.time()
    tempototal = tempoFinal - tempoInicio
    PlotTempoExecucao.append(tempototal)

# %% [markdown]
# # DEAP - ONEMAX

# %%
from deap import base
from deap import creator
from deap import tools
from deap import creator, base, tools, algorithms
import random

# %%
'''
    1) OneMax
    2) DFS
    3) Distancia percorrida DFS
    4) tamanho do ciclo
    5) distancia do trajeto da rota
'''
creator.create("FitnessMulti", base.Fitness, weights=(feature1, feature2, feature3, feature4, feature5))
creator.create("Individual", list, fitness=creator.FitnessMulti)

def evalFitness(individual):
    '''
        Retorno do método
        contListaPercorrida, distanciaFinal, tamanhoCicloRetorno, distanciaCicloRetorno
    '''
    tamDFS, distanciaDFS, tamanhoCiclo, distanciaCiclo = temCicloDFS(individual)
    return np.sum(individual), tamDFS, distanciaDFS, tamanhoCiclo, distanciaCiclo
    


toolbox = base.Toolbox()
toolbox.register("bit", random.randint, 0, 1)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.bit, tamGenes)
toolbox.register("population", tools.initRepeat, list, toolbox.individual, n=tamPopulacao)
toolbox.register("evaluate", evalFitness)
toolbox.register("mate", tools.cxUniform, indpb=0.1)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selNSGA2)



def main():
    
    #random.seed(SEED_RANDOM)   
    population = toolbox.population()
    fits = toolbox.map(toolbox.evaluate, population)
    
    for fit, ind in zip(fits, population):
        ind.fitness.values = fit
    
    print("Start of evolution")
            
    for gen in range(totGeracoes):
        
        tempoInicio = time.time()
        
        print('GERAÇÃO: {}'.format(gen+1))
        offspring = algorithms.varOr(population, toolbox, lambda_=tamPopulacao, cxpb=0.5, mutpb=0.1)
        fits = toolbox.map(toolbox.evaluate, offspring)
        
        l_onemax = []
        l_dfs = []
        l_dist = []
        l_tam_ciclo = []
        l_dist_ciclo = []
        
        for fit, ind in zip(fits, offspring):
            ind.fitness.values = fit            
            x, y, z, w, v = fit
            l_onemax.append(x)
            l_dfs.append(y)
            l_dist.append(z)
            l_tam_ciclo.append(w)
            l_dist_ciclo.append(v)
            
        population = toolbox.select(offspring + population, k=tamPopulacao)
        
        # ONEMAX
        #calc_objetivo_1(l_onemax)        
        thread_ob_1 = threading.Thread(target=calc_objetivo_1, args=[1,l_onemax])
        thread_ob_1.start()
        
        # DFS
        #calc_objetivo_2(l_dfs)
        thread_ob_2 = threading.Thread(target=calc_objetivo_2, args=[2,l_dfs])
        thread_ob_2.start()
        
        # DISTÂNCIA
        #calc_objetivo_3(l_dist)
        thread_ob_3 = threading.Thread(target=calc_objetivo_3, args=[3,l_dist] )
        thread_ob_3.start()
        
        # Tamanho Ciclo
        #calc_objetivo_4(l_tam_ciclo)
        thread_ob_4 = threading.Thread(target=calc_objetivo_4, args=[4,l_tam_ciclo])
        thread_ob_4.start()
        
        # tamanho da rota Ciclica
        #calc_objetivo_5(l_dist_ciclo)
        thread_ob_5 = threading.Thread(target=calc_objetivo_5, args=[5,l_dist_ciclo])
        thread_ob_5.start()
        
        timeExecuteGeneration(tempoInicio)
        
    print("-- End of (successful) evolution --")
        
if __name__ == "__main__":
    main()
# Out:
# Start of evolution
#
# GERAÇÃO: 1
#
# GERAÇÃO: 2
#
# GERAÇÃO: 3
#
# GERAÇÃO: 4
#
# GERAÇÃO: 5
#
# GERAÇÃO: 6
#
# GERAÇÃO: 7
#
# GERAÇÃO: 8
#
# GERAÇÃO: 9
#
# GERAÇÃO: 10
#
# GERAÇÃO: 11
#
# GERAÇÃO: 12
#
# GERAÇÃO: 13
#
# GERAÇÃO: 14
#
# GERAÇÃO: 15
#
# GERAÇÃO: 16
#
# GERAÇÃO: 17
#
# GERAÇÃO: 18
#
# GERAÇÃO: 19
#
# GERAÇÃO: 20
#
# GERAÇÃO: 21
#
# GERAÇÃO: 22
#
# GERAÇÃO: 23
#
# GERAÇÃO: 24
#
# GERAÇÃO: 25
#
# GERAÇÃO: 26
#
# GERAÇÃO: 27
#
# GERAÇÃO: 28
#
# GERAÇÃO: 29
#
# GERAÇÃO: 30
#
# GERAÇÃO: 31
#
# GERAÇÃO: 32
#
# GERAÇÃO: 33
#
# GERAÇÃO: 34
#
# GERAÇÃO: 35
#
# GERAÇÃO: 36
#
# GERAÇÃO: 37
#
# GERAÇÃO: 38
#
# GERAÇÃO: 39
#
# GERAÇÃO: 40
#
# GERAÇÃO: 41
#
# GERAÇÃO: 42
#
# GERAÇÃO: 43
#
# GERAÇÃO: 44
#
# GERAÇÃO: 45
#
# GERAÇÃO: 46
#
# GERAÇÃO: 47
#
# GERAÇÃO: 48
#
# GERAÇÃO: 49

# %% [markdown]
# # Gráfico da Evolução do AG dentre as gerações com máximo, média e mínimo

# %%
# fazer um tratamento se o maxdados for o valor de sinalização para remove-lo da lista para nao estragar o gráfico
plt.figure(figsize=(16,6))
plt.plot(PlotMaxDadosONEMAX, 'ob--' , label='MAX')
plt.plot(PlotMeanDadosONEMAX, 'or--' ,label='MEAN')
plt.plot(PlotMinDadosONEMAX, 'og--',label='MIN')
plt.xlabel('Gerações')
plt.ylabel('Total de Arestas Selecionadas')
plt.title('Evolução do Algoritmo Genético NSGA2 - Feature ONEMAX')
plt.legend(loc='upper left')
plt.savefig("images/GraficoONEMAX.pdf",format="pdf")
#plt.show()

# %%
#
# fazer um tratamento se o maxdados for o valor de sinalização para remove-lo da lista para nao estragar o gráfico
plt.figure(figsize=(16,6))
plt.plot(PlotMaxDadosDFS, 'ob--' , label='MAX')
plt.plot(PlotMeanDadosDFS, 'or--' ,label='MEAN')
plt.plot(PlotMinDadosDFS, 'og--',label='MIN')
plt.xlabel('Gerações')
plt.ylabel('Arestas Percorridas')
plt.title('Evolução Algoritmo Genético NSGA2 - Feature Busca em profundidade')
plt.legend(loc='upper left')
plt.savefig("images/GraficoDFS.pdf",format=formato_imgs)
#plt.show()

# %%
#
# Distancia percorrida DFS
plt.figure(figsize=(16,6))
plt.plot(PlotMinDistDFS, 'ob--' , label='MAX')
plt.plot(PlotMeanDistDFS, 'or--' ,label='MEAN')
plt.plot(PlotMaxDistDFS, 'og--',label='MIN')
plt.xlabel('Gerações')
plt.ylabel('Distância percorrida pela Busca em Profundidade')
plt.title('Evolução Algoritmo Genético NSGA2 - Distância percorrida pela DFS')
plt.legend(loc='upper left')
plt.savefig("images/GraficoDistanciaPercorridaDFS.pdf",format=formato_imgs)
#plt.show()

# %%
#
# Distancia percorrida DFS
plt.figure(figsize=(16,6))
plt.plot(PlotMinTamCiclo, 'ob--' , label='MAX')
plt.plot(PlotMeanTamCiclo, 'or--' ,label='MEAN')
plt.plot(PlotMaxTamCiclo, 'og--',label='MIN')
plt.xlabel('Gerações')
plt.ylabel('Tamanho do Ciclo')
plt.title('Evolução Algoritmo Genético NSGA2 - Feature Tamanho do Ciclo em Arestas')
plt.legend(loc='upper left')
plt.savefig("images/GraficoTotArestasCiclo.pdf",format=formato_imgs)
#plt.show()

# %%
#
# Distancia percorrida DFS
plt.figure(figsize=(16,6))
plt.plot(PlotMinDistCiclo, 'ob--' , label='MAX')
plt.plot(PlotMeanDistCiclo, 'or--' ,label='MEAN')
plt.plot(PlotMaxDistCiclo, 'og--',label='MIN')
plt.xlabel('Gerações')
plt.ylabel('Distância percorrida pela Busca em Profundidade')
plt.title('Evolução Algoritmo Genético NSGA-2 - Feature Distância do Percurso da Rota')
plt.legend(loc='upper left')
plt.savefig("images/GraficoTamCicloRota.pdf",format=formato_imgs)
#plt.show()

# %%
#
# Distancia percorrida DFS
plt.figure(figsize=(16,6))
plt.plot(PlotTempoExecucao, 'ob--' , label='Tempo')
plt.xlabel('Gerações')
plt.ylabel('Tempo de execução em cada geração')
plt.title('Tempo de Execução Em Cada Geração - Algoritmo Genético NSGA-2')
plt.legend(loc='upper left')
plt.savefig("images/GraficoTempoExecucao.pdf",format=formato_imgs)
#plt.show()

# %%
#
# Evolução dos ciclos encontrados
plt.figure(figsize=(16,6))
plt.plot(PlotMaioresCiclos, 'ob--' , label='Ciclos')
plt.xlabel('Ciclo i')
plt.ylabel('Tamanho de Ciclos')
plt.title('Evolução dos ciclos encontrados')
plt.legend(loc='upper left')
plt.savefig("images/GraficoTamanhoCiclos.pdf",format=formato_imgs)
#plt.show()

# %% [markdown]
# # Plotagem das rotas geradas caso tenha encontrado

# %%
def salvarRotaTxt(via_vez, rota):
    try:
        path = "Rotas/Rota-"+str(via_vez)+".txt"
        arq = open(path, 'w')    
        for linha in rota:
            arq.write(linha+"\n")        
        arq.close()
    except:
        print("Erro salvar rota..")
    
def printFormatNamesStreet( via_vez , qtd_arestas, ruas ):
    
    try:
        contador = 1
        salvarText = []

        # +1 por causa do retorno do ciclo da rota    
        Rota = "Rota "+str(via_vez)+" - "+str(qtd_arestas)+" Arestas:\n"
        print(Rota)
        salvarText.append(Rota)

        for rua in ruas:
            concat = str(rua)
            Rua = ""+str(contador)+"ª - "+concat
            print(Rua)
            salvarText.append(Rua)
            contador = contador + 1

        Rua = ""+str(contador)+"ª - "+ruas[0]
        print(Rua)
        salvarText.append(Rua)

        salvarRotaTxt(via_vez, salvarText)
    except:
        print("Erro pegar rota..")
        
def printRotaRuas(via_vez, qtd_arestas, rota ):
    '''
    print(listaDadosNew[0])
    print()
    print(listaDadosNew[0][0])
    print()
    print(listaDadosNew[0][1])
    print()
    print(listaDadosNew[0][2])
    print()
    print(listaDadosNew[0][2]['name'])
    
    [321519672, 3589971255, {'osmid': 704201746, 'oneway': True, 'name': 'Rua Coronel Pinto', 'highway': 'tertiary', 'length': 18.205}]

    321519672

    3589971255

    {'osmid': 704201746, 'oneway': True, 'name': 'Rua Coronel Pinto', 'highway': 'tertiary', 'length': 18.205}

    Rua Coronel Pinto
    
    '''
    try:
                
        tamListaDadosNew = len(listaDadosNew)
        tamRotaLista = len(rota)

        ruasRota = []

        '''
            Arrumar os nomes das ruas..
        '''


        for rota_i in range( tamRotaLista ):            
            for lista_i in range(tamListaDadosNew):            
                if( listaDadosNew[lista_i][0] == rota[rota_i][0] and listaDadosNew[lista_i][1] == rota[rota_i][1] ):

                    if 'name' in listaDadosNew[lista_i][2]:
                        rua = listaDadosNew[lista_i][2]['name']

                        if rua not in ruasRota:
                            ruasRota.append(rua)

                    else:
                        ruasRota.append("Unname")

                    '''
                    print(listaDadosNew[lista_i])
                    print(rota[rota_i])
                    print()
                    '''                    

        printFormatNamesStreet(via_vez, qtd_arestas, ruasRota )
        print("\n\n")

    except:
        print("Erro...")

# %%
#create list router

def transformListRoute(route):
    router = []
    
    for i, j in route:
        router.append(i)
        #router.append(j)    
    router.append(router[0])
    
    return router

# %%
removerNodosFinal = []
cont=1
contador = 0
if len(listaResultadoDFS) > 0:
    for cadaCicloEncontrado in range(len(listaResultadoDFS)):
        contador = contador + 1        
        
        for nodos in listaDadosNew:
            v = (nodos[0], nodos[1])

            if v not in listaResultadoDFS[ cadaCicloEncontrado ]:
                removerNodosFinal.append(v)
        
        if len(removerNodosFinal) > 0:
            #G_aux = G.copy()
            #G_aux.remove_edges_from(removerNodosFinal)
         
            # para salvar
            name = "Rota-"+ str(contador)
            
            arestas_sel = listaResultadoDFS[cadaCicloEncontrado]
            
            path = [ (u,v) for (u,v, attr) in G.edges(data=True) if (u,v) in arestas_sel]
            
            #fig, ax = ox.plot_graph(G_aux, fig_height=fig_height, fig_width=fig_width, edge_color=edge_color, bgcolor=bgcolor, node_color=node_color, node_size=node_size, filename=name, save=True,  file_format=formato_imgs)
            
            ox.plot.plot_graph_routes(G, path, show=True, fig_height=fig_height, fig_width=fig_width, bgcolor=bgcolor, route_alpha=1, route_linewidth=2, node_size=0 , orig_dest_node_alpha=0, filename=name, save=True,  file_format=formato_imgs )
            #fig, ax = ox.plot_graph(G_aux, fig_height=30, node_color='blue', node_size=5, node_zorder=1, node_edgecolor='k', )
            print("\n")
            #removerNodosFinal.clear()
            
            '''
                Imprimir ruas do trajeto
            '''
            #print(PlotMaioresCiclos)
            printRotaRuas( contador, PlotMaioresCiclos[contador] , listaResultadoDFS[cadaCicloEncontrado] )
            
        
else:
    print("Infelizmente não foi possivel encontrar uma rota....")

# %% [markdown]
#  <h1 style="text-align: center;"> FIMMM --- Obrigado </h1>
