# %%
from _thread import *
from IPython.display import IFrame

import random
import threading
import osmnx as ox
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
try:
    place = 'Boa Vista, Roraima, BR'
    Raio_distancia = 12000

    G = ox.graph_from_address( place, network_type='drive', simplify=True, distance=Raio_distancia )
    
    ox.plot_graph(G, fig_height=20, fig_width=20)
except:
    print("Falha na Conexão!!")

# %%
#G.adj

# %%
def arrumar(nods):
    
    lista = list()
    
    for i in range(len(nods)-1):
        lista.append( (nods[i], nods[i+1]) )
        
    lista
    
    return lista

# %%
names = ['Avenida Ville Roy', 'Capitão Ene Garcez']

nodos = [3648084763, 3589958315, 3589958314, 3589958313, 321519687, 321519687, 1067749186, 1067749046, 1067748783, 1067748594, 1067749172, 321520743, 321519672, 321519672, 3648084764, 3648084758, 3648084763]

nodos = [ int(n) for n in nodos ]

paths = arrumar(nodos)


#path = [ (u,v) for (u,v, attr) in G.edges(data=True) if u in nodos and v in nodos]

path = [ (u,v) for (u,v, attr) in G.edges(data=True) if (u,v) in paths]

path
# Out:
# [(321519672, 3648084764),
#  (321519687, 1067749186),
#  (321520743, 321519672),
#  (3648084758, 3648084763),
#  (3648084763, 3589958315),
#  (3648084764, 3648084758),
#  (3589958313, 321519687),
#  (3589958314, 3589958313),
#  (3589958315, 3589958314),
#  (1067748594, 1067749172),
#  (1067748783, 1067748594),
#  (1067749046, 1067748783),
#  (1067749172, 321520743),
#  (1067749186, 1067749046)]

# %%
ox.plot.plot_graph_routes(G, path, show=True, fig_height=40, route_alpha=1, route_linewidth=2, node_size=0 , orig_dest_node_alpha=0 )
# Out:
# (<Figure size 3033.59x2880 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f953c7e2908>)
